# %% [markdown]
# <h1 style='color: #0000b0'> GDO 23º BPM - MAIO/2020</h1>
# <h2 style='color: #008000'></h2>

# %%
# %run -i funcs_armazem.py
# bd_dados, tables = get_gdo_tables('parcial')
bd_dados, tables = get_gdo_tables('mes_fechado', 6)
show_tables(tables)
# Out:
# WARNING *** file size (1732039) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# <style  type="text/css" >
#     #T_6c72c32c_c20f_11ea_9d7f_7352bbe90f37row0_col0 {
#             text-align:  center;
#         }    #T_6c72c32c_c20f_11ea_9d7f_7352bbe90f37row0_col1 {
#             text-align:  center;
#         }    #T_6c72c32c_c20f_11ea_9d7f_7352bbe90f37row0_col2 {
#             text-align:  center;
#         }    #T_6c72c32c_c20f_11ea_9d7f_7352bbe90f37row0_col3 {
#             text-align:  center;
#         }    #T_6c72c32c_c20f_11ea_9d7f_7352bbe90f37row0_col4 {
#             text-align:  center;
#         }    #T_6c72c32c_c20f_11ea_9d7f_7352bbe90f37row0_col5 {
#             text-align:  center;
#         }    #T_6c72c32c_c20f_11ea_9d7f_7352bbe90f37row0_col6 {
#             text-align:  center;
#         }    #T_6c72c32c_c20f_11ea_9d7f_7352bbe90f37row0_col7 {
#             text-align:  center;
#
# ...
